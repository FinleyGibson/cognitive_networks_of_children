# %%
import pandas as pd
import seaborn as sns

# %%
chdf = pd.read_json("../data/processed/basic_dataframe.json")
chdf
# Out:
#                                                          speech  \
# NDARKW521EMY  No. Okay. The pup, he was playing video games....
# NDARYF135ZHU  No. It's about a boy who plays video games a l...
# NDARWW003WWW  Yeah. The kid that was playing a video game, a...
# NDARFK477WX9  No. It began ... The boy was playing a game an...
# NDARZY668NMV  No. Well I don't know who  got all of it of co...
# ...                                                         ...
# NDARHU211PYD  Yup.  Oh. He played a game. Then his mother ca...
# NDARWV449GEM  You mean Despicable Me 3? Puppy Dog Pals? The ...
# NDARUW000ALJ  No. I haven't. Yeah. What movie? The boy lost ...
# NDARYZ363HP4  Yeah. Yeah. It was not working. Why was it not...
# NDARJB027GMR  Yeah. That movie is fun. I don't know what to ...
#
#                                                       sentences  \
# NDARKW521EMY  [No., Okay., The pup, he was playing video gam...
# NDARYF135ZHU  [No., It's about a boy who plays video games a...
# ...

# %%
# example plot: histogram of number of words in each formamentis network
fmn_lengths = chdf["vertices"].apply(lambda x: len(x))
fig = sns.histplot(fmn_lengths)
fig.set_xlabel("Words in formamentis network")
# Out:
# Text(0.5, 0, 'Words in formamentis network')
